# %%
import pandas as pd

# %%
df = pd.read_csv("./base/base.csv", encoding='UTF-8')

# %%
dfWithoutAutor = df[df["autor"] != "btgpactual"]

# %%
dfWithoutAutor.to_csv(r'C:\Users\eduar\github\SI\Projeto4\output\dfWithoutAutor2.csv', index=False, header=True)

# %%
dfWithoutNull = dfWithoutAutor[dfWithoutAutor['autor'].notnull()]

# %%
dfWithoutNull
# Out:
#       Column1       id                  autor
# 4           4        5                         \
# 10         10       11  matheusriosortodontia
# 13         13       14           erikacoimbra
# 14         14       15         anapaulanakade
# 15         15       16           rosanakassar
# ...       ...      ...                    ...
# 4542     4542  3028275            gui.decicco
# 4543     4543  3028307             giballiana
# 4544     4544  3028308          caioaugustofr
# 4547     4547  3029097         je_mascarenhas
# 4548     4548  3029149              linequer_
#
#                                                   texto    shortCode
# 4     Oi, Nelson! Tudo bem?\r\n\r\nPossuímos soluçõe...  CkG9KXjpY2B  \
# 10    @gustavopaulinno Realmente. Ja rodei por aí e ...  CkG9KXjpY2B
# 13                                                  👏👏👏  CkG9KXjpY2B
# 14    O app está travando desde ontem, está em manut...  CkG9KXjpY2B
# ...

# %%
dfFinal = dfWithoutNull[dfWithoutNull["tipoInteracao"] == "comment"]

# %%
dfFinal[0:60]
# Out:
#     Column1  id                    autor
# 13       13  14             erikacoimbra  \
# 14       14  15           anapaulanakade
# 15       15  16             rosanakassar
# 16       16  17  luizantoniojovinodossan
# 17       17  18              ronialencar
# 18       18  19             calosjealous
# 19       19  20           nelson.proteja
# 20       20  21            bastosroberio
# 21       21  22                 drmilior
# 22       22  23           galdino.runner
# 23       23  24            ronisantos180
# 24       24  25            thlimaoficial
# 25       25  26          gustavopaulinno
# 26       26  27          diego_antunescf
# 41       41  42                lzz_costa
# 42       42  43        wenio.oliveira.df
# 43       43  44               elisalugao
# 44       44  45      luiz_a.j.dos_santos
# 45       45  46             nuno_scariot
# 46       46  47    luciano_fernandes.sim
# 47       47  48           carolin4castro
# 48       48  49            gustavocraupp
# ...

# %%
dfFinal.to_csv(r'C:\Users\eduar\github\SI\Projeto4\output\dfClean2.csv',encoding='utf-16', index=False, header=True, )
