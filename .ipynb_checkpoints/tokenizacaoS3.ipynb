# %%
import nltk  # import the Natural Language Toolkit library
from nltk.tokenize import word_tokenize  # import the word_tokenize function from the NLTK library
from nltk.corpus import stopwords  # import the stopwords from the NLTK library
import string  # import the string module
import pandas as pd  # import the pandas library and rename it as pd
from nltk import tokenize  # import the tokenize module from the NLTK library


drive.mount('/content/drive')  # mount the Google Drive in the Colab environment

# %%
nltk.download('punkt')  # download the NLTK package for tokenization
drive.mount('/content/drive')  # mount the Google Drive in the Colab environment

# %%
df = pd.read_excel('/content/drive/MyDrive/bdm6/BASE-ATUAL.xlsx')
# read an Excel file named 'BASE-ATUAL.xlsx' from Google Drive into a pandas dataframe named 'df'
df["texto_tokenizado"] = df['"texto"'].apply(lambda x: word_tokenize(x))  # tokenize the 'texto' column of the dataframe and add a new column named 'texto_tokenizado' with the tokenized text
df  # display the resulting dataframe
# Out:
#       Column1       id           autor
# 0           0        1      btgpactual  \
# 1           1        2      btgpactual
# 2           2        3      btgpactual
# 3           3        4      btgpactual
# 4           4        5
# ...       ...      ...             ...
# 4544     4544  3028308   caioaugustofr
# 4545     4545  3028501      btgpactual
# 4546     4546  3028580      btgpactual
# 4547     4547  3029097  je_mascarenhas
# 4548     4548  3029149       linequer_
#
#                                                   texto    shortCode
# 0     Olá, Ana Paula! Como vai?\r\n\r\nSentimos muit...  CkG9KXjpY2B  \
# 1     Olá, Rosana! Tudo bem?\r\n\r\nPara te orientar...  CkG9KXjpY2B
# 2                          @luizantoniojovinodossan 🚀 💙  CkG9KXjpY2B
# 3     @ronialencar Boa tarde! Tudo bem?\r\n\r\nLamen...  CkG9KXjpY2B
# 4     Oi, Nelson! Tudo bem?\r\n\r\nPossuímos soluçõe...  CkG9KXjpY2B
# ...                                                 ...          ...
# ...
