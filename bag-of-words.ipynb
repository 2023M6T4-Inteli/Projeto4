# %%
import pandas as pd

# %%
df = pd.read_csv("./base/base.csv", encoding='UTF-8')

# %%
# this function cleans up data that will not be used in the model
def cleanData(df):
    #remove comments made by btg
    dfWithoutAutor = df[df["autor"] != "btgpactual"]
    #remove comments with null authors
    dfWithoutNull = dfWithoutAutor[dfWithoutAutor['autor'].notnull()]
    #leave only the comment texts
    dfFinal = dfWithoutNull.loc[(dfWithoutNull['tipoInteracao'] == 'comment') | (dfWithoutNull['tipoInteracao'] == 'reply')]
    return dfFinal

# %%
df1 = cleanData(df)

# %%
df1
# Out:
#       Column1       id                  autor  \
# 4           4        5
# 10         10       11  matheusriosortodontia
# 13         13       14           erikacoimbra
# 14         14       15         anapaulanakade
# 15         15       16           rosanakassar
# ...       ...      ...                    ...
# 4538     4538  3027573   viniciuscavalcante01
# 4543     4543  3028307             giballiana
# 4544     4544  3028308          caioaugustofr
# 4547     4547  3029097         je_mascarenhas
# 4548     4548  3029149              linequer_
#
#                                                   texto    shortCode  \
# 4     Oi, Nelson! Tudo bem?\n\nPossuímos soluções co...  CkG9KXjpY2B
# 10    @gustavopaulinno Realmente. Ja rodei por aí e ...  CkG9KXjpY2B
# 13                                                  👏👏👏  CkG9KXjpY2B
# 14    O app está travando desde ontem, está em manut...  CkG9KXjpY2B
# 15    Abri uma conta, mas achei muito complicado inv...  CkG9KXjpY2B
# ...

# %%
df1.to_csv('output\dfCl.csv',encoding='utf-8', index=False, header=True, )
