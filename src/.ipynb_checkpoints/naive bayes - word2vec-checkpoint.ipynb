# %% [markdown]
# ### Naive bayes

# %% [markdown]
# Neste notebook será realizado a aplicação do modelo de naive bayes com dois tipos de word2vec, sendo o primeiro caso utilizando o modelo word2vec feito com o corpus do projeto e a segunda análise com o word2vec pré processado CBOW 50 dimensões" do site do NILC (http://nilc.icmc.usp.br/nilc/index.php/repositorio-de-word-embeddings-do-nilc)

# %% [markdown]
# #### Importando as bibliotecas

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Processando com o word2vec feito com o corpus

# %%
df_corpus = pd.read_csv('../base/word2vec_corpus.csv', index_col=0)

# %%
# Removendo NaN das bases para facilitar o treinamento 
df_without_NaN = df_corpus.dropna()

# %%
df_without_NaN
# Out:
#                                                       Vetor1    Vetor2
# Frase
# ['minuto', 'touro', 'ouro']                         0.229108 -0.510641  \
# ['sim']                                             0.089359 -0.157706
# ['queria', 'saber', 'banking', 'própria']           0.158292 -0.292464
# []                                                 -0.160157 -0.185960
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.144616  0.115510
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.150476 -0.224858
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.179826 -0.317970
# ['atendam', 'telefone', 'amor', 'deus']             0.136935 -0.326340
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.184280 -0.374939
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.138228 -0.300703
#
#                                                       Vetor3    Vetor4
# Frase
# ['minuto', 'touro', 'ouro']                        -0.528357 -0.539646  \
# ['sim']                                            -0.382467 -0.288154
# ['queria', 'saber', 'banking', 'própria']          -0.463430 -0.300576
# []                                                 -0.267293 -0.663145
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.343944 -0.168015
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.401872 -0.363306
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.473730 -0.374198
# ['atendam', 'telefone', 'amor', 'deus']            -0.480037 -0.401130
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.494123 -0.427816
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.495423 -0.381380
#
#                                                       Vetor5    Vetor6
# Frase
# ['minuto', 'touro', 'ouro']                         0.044241  0.190616  \
# ['sim']                                             0.271361  0.183616
# ['queria', 'saber', 'banking', 'própria']           0.062400  0.158551
# []                                                  0.534124  0.049555
# ['palmas', 'palmas', 'palmas', 'palmas']            0.167748  0.183836
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.061161  0.087128
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.065208  0.184645
# ['atendam', 'telefone', 'amor', 'deus']             0.043030  0.166945
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.036561  0.164952
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.048211  0.169756
#
#                                                       Vetor7    Vetor8
# Frase
# ['minuto', 'touro', 'ouro']                        -0.316812 -0.481302  \
# ['sim']                                            -0.230013 -0.484156
# ['queria', 'saber', 'banking', 'própria']          -0.287680 -0.415687
# []                                                 -0.366273 -0.368948
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.210945 -0.349912
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.236299 -0.357250
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.300025 -0.460253
# ['atendam', 'telefone', 'amor', 'deus']            -0.290695 -0.452460
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.293153 -0.492536
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.301047 -0.471167
#
#                                                       Vetor9   Vetor10  ...
# Frase                                                                   ...
# ['minuto', 'touro', 'ouro']                         0.292665  0.152631  ...  \
# ['sim']                                             0.108357  0.124014  ...
# ['queria', 'saber', 'banking', 'própria']           0.145777  0.153554  ...
# []                                                 -0.009452  0.023265  ...
# ['palmas', 'palmas', 'palmas', 'palmas']            0.088331  0.178799  ...
# ...                                                      ...       ...  ...
# ['excelente', 'explicação']                         0.207029  0.034834  ...
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.236172  0.153765  ...
# ['atendam', 'telefone', 'amor', 'deus']             0.257912  0.110724  ...
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.251793  0.120930  ...
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.221697  0.135963  ...
#
#                                                      Vetor42   Vetor43
# Frase
# ['minuto', 'touro', 'ouro']                        -0.217320  0.257045  \
# ['sim']                                            -0.113931  0.239854
# ['queria', 'saber', 'banking', 'própria']          -0.176911  0.229033
# []                                                 -0.304741  0.339400
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.071575  0.274360
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.129704  0.355330
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.174083  0.272439
# ['atendam', 'telefone', 'amor', 'deus']            -0.181774  0.259440
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.173572  0.278620
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.166154  0.268359
#
#                                                      Vetor44   Vetor45
# Frase
# ['minuto', 'touro', 'ouro']                        -0.196502 -0.181537  \
# ['sim']                                            -0.082515 -0.234454
# ['queria', 'saber', 'banking', 'própria']          -0.097036 -0.144796
# []                                                 -0.062100 -0.158935
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.139658 -0.171061
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.187999 -0.189261
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.138258 -0.220851
# ['atendam', 'telefone', 'amor', 'deus']            -0.182321 -0.225408
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.176265 -0.226421
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.160303 -0.203436
#
#                                                      Vetor46   Vetor47
# Frase
# ['minuto', 'touro', 'ouro']                         0.172708  0.030273  \
# ['sim']                                             0.377608  0.313878
# ['queria', 'saber', 'banking', 'própria']           0.198259  0.031119
# []                                                  0.561236  0.286643
# ['palmas', 'palmas', 'palmas', 'palmas']            0.374716  0.410202
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.096097  0.107697
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.185414  0.097092
# ['atendam', 'telefone', 'amor', 'deus']             0.169600  0.115163
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.160225  0.081088
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.189885  0.105900
#
#                                                      Vetor48   Vetor49
# Frase
# ['minuto', 'touro', 'ouro']                         0.025029 -0.025549  \
# ['sim']                                            -0.051470 -0.175528
# ['queria', 'saber', 'banking', 'própria']          -0.050245 -0.107662
# []                                                 -0.035090 -0.045580
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.115234 -0.254348
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.019012 -0.089640
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.032127 -0.093672
# ['atendam', 'telefone', 'amor', 'deus']             0.006588 -0.101710
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.017019 -0.075075
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.015824 -0.106362
#
#                                                      Vetor50  sentimento
# Frase
# ['minuto', 'touro', 'ouro']                        -0.114576           1
# ['sim']                                            -0.107952           0
# ['queria', 'saber', 'banking', 'própria']          -0.178710           1
# []                                                 -0.129499           0
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.283959           0
# ...                                                      ...         ...
# ['excelente', 'explicação']                        -0.157856           1
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.174149          -1
# ['atendam', 'telefone', 'amor', 'deus']            -0.168454           1
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.146576           1
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.173936          -1
#
# [6356 rows x 51 columns]

# %% [markdown]
# #### Label encoding

# %% [markdown]
# O label encoding é feito para permitir com que o modelo interprete os diferentes resultados da váriavel alvo.
# Nesta etapa os labels retornam o seguinte resultado :
#
# - POSITIVO = 2
#
# - NEUTRO = 1
#
# - NEGATIVO = 0

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(df_without_NaN['sentimento'])
df_without_NaN['sentimento'] = le.transform(df_without_NaN['sentimento'])

# %%
# Demonstrando o resultado do label encoding
df_without_NaN
# Out:
#                                                       Vetor1    Vetor2
# Frase
# ['minuto', 'touro', 'ouro']                         0.229108 -0.510641  \
# ['sim']                                             0.089359 -0.157706
# ['queria', 'saber', 'banking', 'própria']           0.158292 -0.292464
# []                                                 -0.160157 -0.185960
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.144616  0.115510
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.150476 -0.224858
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.179826 -0.317970
# ['atendam', 'telefone', 'amor', 'deus']             0.136935 -0.326340
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.184280 -0.374939
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.138228 -0.300703
#
#                                                       Vetor3    Vetor4
# Frase
# ['minuto', 'touro', 'ouro']                        -0.528357 -0.539646  \
# ['sim']                                            -0.382467 -0.288154
# ['queria', 'saber', 'banking', 'própria']          -0.463430 -0.300576
# []                                                 -0.267293 -0.663145
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.343944 -0.168015
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.401872 -0.363306
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.473730 -0.374198
# ['atendam', 'telefone', 'amor', 'deus']            -0.480037 -0.401130
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.494123 -0.427816
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.495423 -0.381380
#
#                                                       Vetor5    Vetor6
# Frase
# ['minuto', 'touro', 'ouro']                         0.044241  0.190616  \
# ['sim']                                             0.271361  0.183616
# ['queria', 'saber', 'banking', 'própria']           0.062400  0.158551
# []                                                  0.534124  0.049555
# ['palmas', 'palmas', 'palmas', 'palmas']            0.167748  0.183836
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.061161  0.087128
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.065208  0.184645
# ['atendam', 'telefone', 'amor', 'deus']             0.043030  0.166945
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.036561  0.164952
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.048211  0.169756
#
#                                                       Vetor7    Vetor8
# Frase
# ['minuto', 'touro', 'ouro']                        -0.316812 -0.481302  \
# ['sim']                                            -0.230013 -0.484156
# ['queria', 'saber', 'banking', 'própria']          -0.287680 -0.415687
# []                                                 -0.366273 -0.368948
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.210945 -0.349912
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.236299 -0.357250
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.300025 -0.460253
# ['atendam', 'telefone', 'amor', 'deus']            -0.290695 -0.452460
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.293153 -0.492536
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.301047 -0.471167
#
#                                                       Vetor9   Vetor10  ...
# Frase                                                                   ...
# ['minuto', 'touro', 'ouro']                         0.292665  0.152631  ...  \
# ['sim']                                             0.108357  0.124014  ...
# ['queria', 'saber', 'banking', 'própria']           0.145777  0.153554  ...
# []                                                 -0.009452  0.023265  ...
# ['palmas', 'palmas', 'palmas', 'palmas']            0.088331  0.178799  ...
# ...                                                      ...       ...  ...
# ['excelente', 'explicação']                         0.207029  0.034834  ...
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.236172  0.153765  ...
# ['atendam', 'telefone', 'amor', 'deus']             0.257912  0.110724  ...
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.251793  0.120930  ...
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.221697  0.135963  ...
#
#                                                      Vetor42   Vetor43
# Frase
# ['minuto', 'touro', 'ouro']                        -0.217320  0.257045  \
# ['sim']                                            -0.113931  0.239854
# ['queria', 'saber', 'banking', 'própria']          -0.176911  0.229033
# []                                                 -0.304741  0.339400
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.071575  0.274360
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.129704  0.355330
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.174083  0.272439
# ['atendam', 'telefone', 'amor', 'deus']            -0.181774  0.259440
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.173572  0.278620
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.166154  0.268359
#
#                                                      Vetor44   Vetor45
# Frase
# ['minuto', 'touro', 'ouro']                        -0.196502 -0.181537  \
# ['sim']                                            -0.082515 -0.234454
# ['queria', 'saber', 'banking', 'própria']          -0.097036 -0.144796
# []                                                 -0.062100 -0.158935
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.139658 -0.171061
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.187999 -0.189261
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.138258 -0.220851
# ['atendam', 'telefone', 'amor', 'deus']            -0.182321 -0.225408
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.176265 -0.226421
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.160303 -0.203436
#
#                                                      Vetor46   Vetor47
# Frase
# ['minuto', 'touro', 'ouro']                         0.172708  0.030273  \
# ['sim']                                             0.377608  0.313878
# ['queria', 'saber', 'banking', 'própria']           0.198259  0.031119
# []                                                  0.561236  0.286643
# ['palmas', 'palmas', 'palmas', 'palmas']            0.374716  0.410202
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.096097  0.107697
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.185414  0.097092
# ['atendam', 'telefone', 'amor', 'deus']             0.169600  0.115163
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.160225  0.081088
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.189885  0.105900
#
#                                                      Vetor48   Vetor49
# Frase
# ['minuto', 'touro', 'ouro']                         0.025029 -0.025549  \
# ['sim']                                            -0.051470 -0.175528
# ['queria', 'saber', 'banking', 'própria']          -0.050245 -0.107662
# []                                                 -0.035090 -0.045580
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.115234 -0.254348
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.019012 -0.089640
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.032127 -0.093672
# ['atendam', 'telefone', 'amor', 'deus']             0.006588 -0.101710
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.017019 -0.075075
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.015824 -0.106362
#
#                                                      Vetor50  sentimento
# Frase
# ['minuto', 'touro', 'ouro']                        -0.114576           2
# ['sim']                                            -0.107952           1
# ['queria', 'saber', 'banking', 'própria']          -0.178710           2
# []                                                 -0.129499           1
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.283959           1
# ...                                                      ...         ...
# ['excelente', 'explicação']                        -0.157856           2
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.174149           0
# ['atendam', 'telefone', 'amor', 'deus']            -0.168454           2
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.146576           2
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.173936           0
#
# [6356 rows x 51 columns]

# %% [markdown]
# ### Separando o dataset em treino e teste

# %% [markdown]
# O Dataset é necessário

# %%
target_corpus = df_without_NaN['sentimento']

# %%
features_corpus = df_without_NaN.iloc[:,0:50]

# %%
features_corpus
# Out:
#                                                       Vetor1    Vetor2
# Frase
# ['minuto', 'touro', 'ouro']                         0.229108 -0.510641  \
# ['sim']                                             0.089359 -0.157706
# ['queria', 'saber', 'banking', 'própria']           0.158292 -0.292464
# []                                                 -0.160157 -0.185960
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.144616  0.115510
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.150476 -0.224858
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.179826 -0.317970
# ['atendam', 'telefone', 'amor', 'deus']             0.136935 -0.326340
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.184280 -0.374939
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.138228 -0.300703
#
#                                                       Vetor3    Vetor4
# Frase
# ['minuto', 'touro', 'ouro']                        -0.528357 -0.539646  \
# ['sim']                                            -0.382467 -0.288154
# ['queria', 'saber', 'banking', 'própria']          -0.463430 -0.300576
# []                                                 -0.267293 -0.663145
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.343944 -0.168015
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.401872 -0.363306
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.473730 -0.374198
# ['atendam', 'telefone', 'amor', 'deus']            -0.480037 -0.401130
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.494123 -0.427816
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.495423 -0.381380
#
#                                                       Vetor5    Vetor6
# Frase
# ['minuto', 'touro', 'ouro']                         0.044241  0.190616  \
# ['sim']                                             0.271361  0.183616
# ['queria', 'saber', 'banking', 'própria']           0.062400  0.158551
# []                                                  0.534124  0.049555
# ['palmas', 'palmas', 'palmas', 'palmas']            0.167748  0.183836
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.061161  0.087128
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.065208  0.184645
# ['atendam', 'telefone', 'amor', 'deus']             0.043030  0.166945
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.036561  0.164952
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.048211  0.169756
#
#                                                       Vetor7    Vetor8
# Frase
# ['minuto', 'touro', 'ouro']                        -0.316812 -0.481302  \
# ['sim']                                            -0.230013 -0.484156
# ['queria', 'saber', 'banking', 'própria']          -0.287680 -0.415687
# []                                                 -0.366273 -0.368948
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.210945 -0.349912
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.236299 -0.357250
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.300025 -0.460253
# ['atendam', 'telefone', 'amor', 'deus']            -0.290695 -0.452460
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.293153 -0.492536
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.301047 -0.471167
#
#                                                       Vetor9   Vetor10  ...
# Frase                                                                   ...
# ['minuto', 'touro', 'ouro']                         0.292665  0.152631  ...  \
# ['sim']                                             0.108357  0.124014  ...
# ['queria', 'saber', 'banking', 'própria']           0.145777  0.153554  ...
# []                                                 -0.009452  0.023265  ...
# ['palmas', 'palmas', 'palmas', 'palmas']            0.088331  0.178799  ...
# ...                                                      ...       ...  ...
# ['excelente', 'explicação']                         0.207029  0.034834  ...
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.236172  0.153765  ...
# ['atendam', 'telefone', 'amor', 'deus']             0.257912  0.110724  ...
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.251793  0.120930  ...
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.221697  0.135963  ...
#
#                                                      Vetor41   Vetor42
# Frase
# ['minuto', 'touro', 'ouro']                         0.250459 -0.217320  \
# ['sim']                                             0.305007 -0.113931
# ['queria', 'saber', 'banking', 'própria']           0.226260 -0.176911
# []                                                  0.733899 -0.304741
# ['palmas', 'palmas', 'palmas', 'palmas']            0.237319 -0.071575
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.226970 -0.129704
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.222650 -0.174083
# ['atendam', 'telefone', 'amor', 'deus']             0.229433 -0.181774
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.235954 -0.173572
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.241234 -0.166154
#
#                                                      Vetor43   Vetor44
# Frase
# ['minuto', 'touro', 'ouro']                         0.257045 -0.196502  \
# ['sim']                                             0.239854 -0.082515
# ['queria', 'saber', 'banking', 'própria']           0.229033 -0.097036
# []                                                  0.339400 -0.062100
# ['palmas', 'palmas', 'palmas', 'palmas']            0.274360 -0.139658
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.355330 -0.187999
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.272439 -0.138258
# ['atendam', 'telefone', 'amor', 'deus']             0.259440 -0.182321
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.278620 -0.176265
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.268359 -0.160303
#
#                                                      Vetor45   Vetor46
# Frase
# ['minuto', 'touro', 'ouro']                        -0.181537  0.172708  \
# ['sim']                                            -0.234454  0.377608
# ['queria', 'saber', 'banking', 'própria']          -0.144796  0.198259
# []                                                 -0.158935  0.561236
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.171061  0.374716
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.189261  0.096097
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.220851  0.185414
# ['atendam', 'telefone', 'amor', 'deus']            -0.225408  0.169600
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.226421  0.160225
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.203436  0.189885
#
#                                                      Vetor47   Vetor48
# Frase
# ['minuto', 'touro', 'ouro']                         0.030273  0.025029  \
# ['sim']                                             0.313878 -0.051470
# ['queria', 'saber', 'banking', 'própria']           0.031119 -0.050245
# []                                                  0.286643 -0.035090
# ['palmas', 'palmas', 'palmas', 'palmas']            0.410202 -0.115234
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.107697 -0.019012
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.097092 -0.032127
# ['atendam', 'telefone', 'amor', 'deus']             0.115163  0.006588
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.081088  0.017019
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.105900 -0.015824
#
#                                                      Vetor49   Vetor50
# Frase
# ['minuto', 'touro', 'ouro']                        -0.025549 -0.114576
# ['sim']                                            -0.175528 -0.107952
# ['queria', 'saber', 'banking', 'própria']          -0.107662 -0.178710
# []                                                 -0.045580 -0.129499
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.254348 -0.283959
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.089640 -0.157856
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.093672 -0.174149
# ['atendam', 'telefone', 'amor', 'deus']            -0.101710 -0.168454
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.075075 -0.146576
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.106362 -0.173936
#
# [6356 rows x 50 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features_corpus, target_corpus, test_size=0.2, random_state=42)

# %% [markdown]
# ### Avaliação do modelo

# %%
# Naive Bayes

clf = GaussianNB()

# Train Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
Y_pred = clf.predict(X_test)

print(classification_report(y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.89      0.63       376
#            1       0.85      0.63      0.73       573
#            2       0.36      0.18      0.24       323
#
#     accuracy                           0.59      1272
#    macro avg       0.57      0.57      0.53      1272
# weighted avg       0.62      0.59      0.57      1272

# %%
acc_score = accuracy_score(y_test, Y_pred)
format_output = "{:.2%}".format(acc_score)
print("A precisão foi de :",format_output)
# Out:
# A precisão foi de : 59.36%

# %% [markdown]
# ### Matriz de confusão

# %% [markdown]
# A matriz de confusão tem como objetivo, comparar as predições do modelo com o dataset real. De tal forma, nesse problema de multiclassificação é possível ter um panorama geral das respostas e se o modelo tem algum viés ou não.

# %%
# Criando uma matriz de confusão normalizada
confusion_matrix_corpus = metrics.confusion_matrix(y_test, Y_pred)

# %%
# Criando a matriz e definindo nomes para colunas
cm_corpus = ConfusionMatrixDisplay(confusion_matrix_corpus, display_labels=['Negativo', 'Neutro', 'Positivo'])
cm_corpus.plot()
cm_corpus.ax_.set(
                title='Matriz de confusão Word2Vec corpus', 
                xlabel='Sentimentos previstos', 
                ylabel='Sentimentos reais')
plt.show()

# %% [markdown]
# ## Naive Bayes com o word2vec utilizando vetores pré-treinados

# %% [markdown]
# Nesta etapa iremos utilizar o corpus que já veio vetorizado do site da NILC.

# %%
# Abrindo o dataframe 
df_cbow = pd.read_csv('../output/word2vec_cbow.csv', index_col=0)

# %%
# Removendo NaN das bases para facilitar o treinamento 
df_cbow_NaN = df_cbow.dropna()
df_cbow_NaN
# Out:
#                                                       Vetor1    Vetor2
# Frase
# ['minuto', 'touro', 'ouro']                         0.194111 -0.086163  \
# ['sim']                                             0.109873 -0.062076
# ['queria', 'saber', 'banking', 'própria']           0.121342 -0.183903
# ['palmas', 'palmas', 'palmas', 'palmas']            0.215186 -0.092701
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.208002 -0.119283
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.156762 -0.134906
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.166784 -0.125591
# ['atendam', 'telefone', 'amor', 'deus']             0.136519 -0.113854
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.165214 -0.115387
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.162366 -0.135199
#
#                                                       Vetor3    Vetor4
# Frase
# ['minuto', 'touro', 'ouro']                         0.150576 -0.034733  \
# ['sim']                                             0.187268 -0.213734
# ['queria', 'saber', 'banking', 'própria']           0.268051 -0.031265
# ['palmas', 'palmas', 'palmas', 'palmas']            0.254579 -0.083714
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.219406 -0.040021
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.226852 -0.045667
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.187974 -0.061618
# ['atendam', 'telefone', 'amor', 'deus']             0.161438 -0.110917
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.168456 -0.092509
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.212927 -0.058698
#
#                                                       Vetor5    Vetor6
# Frase
# ['minuto', 'touro', 'ouro']                        -0.066786  0.122470  \
# ['sim']                                             0.046350  0.118452
# ['queria', 'saber', 'banking', 'própria']           0.003071  0.199323
# ['palmas', 'palmas', 'palmas', 'palmas']            0.099877  0.371233
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.008186  0.211272
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.064145  0.179836
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.001240  0.180365
# ['atendam', 'telefone', 'amor', 'deus']             0.034236  0.139376
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.001603  0.144674
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.015598  0.196113
#
#                                                       Vetor7    Vetor8
# Frase
# ['minuto', 'touro', 'ouro']                         0.027893  0.064956  \
# ['sim']                                            -0.025577 -0.149704
# ['queria', 'saber', 'banking', 'própria']          -0.008417  0.046410
# ['palmas', 'palmas', 'palmas', 'palmas']            0.050387 -0.127568
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.019965  0.025391
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.001532 -0.080106
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.004502  0.012454
# ['atendam', 'telefone', 'amor', 'deus']             0.029379 -0.063767
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.017509 -0.001471
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.006022  0.011471
#
#                                                       Vetor9   Vetor10  ...
# Frase                                                                   ...
# ['minuto', 'touro', 'ouro']                         0.005728  0.135925  ...  \
# ['sim']                                             0.143837  0.184814  ...
# ['queria', 'saber', 'banking', 'própria']           0.046311  0.069435  ...
# ['palmas', 'palmas', 'palmas', 'palmas']            0.118620  0.129699  ...
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.058953  0.116330  ...
# ...                                                      ...       ...  ...
# ['excelente', 'explicação']                        -0.059974  0.147371  ...
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.067296  0.108079  ...
# ['atendam', 'telefone', 'amor', 'deus']             0.037123  0.126380  ...
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.037615  0.111353  ...
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.036943  0.071967  ...
#
#                                                      Vetor42   Vetor43
# Frase
# ['minuto', 'touro', 'ouro']                         0.046650 -0.142142  \
# ['sim']                                             0.031963 -0.051879
# ['queria', 'saber', 'banking', 'própria']           0.029866 -0.076881
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.090724  0.021903
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat... -0.018090 -0.062190
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.077624  0.021257
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.006491 -0.059519
# ['atendam', 'telefone', 'amor', 'deus']             0.000793 -0.079159
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.012060 -0.082116
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.005936 -0.051992
#
#                                                      Vetor44   Vetor45
# Frase
# ['minuto', 'touro', 'ouro']                         0.131115  0.063196  \
# ['sim']                                             0.235329 -0.005905
# ['queria', 'saber', 'banking', 'própria']           0.146361  0.077992
# ['palmas', 'palmas', 'palmas', 'palmas']            0.221911  0.072890
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.159715  0.074844
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.139206  0.068294
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.148439  0.087409
# ['atendam', 'telefone', 'amor', 'deus']             0.139690  0.086531
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.126618  0.089894
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.136300  0.082029
#
#                                                      Vetor46   Vetor47
# Frase
# ['minuto', 'touro', 'ouro']                         0.025213  0.094671  \
# ['sim']                                             0.000182 -0.029570
# ['queria', 'saber', 'banking', 'própria']          -0.022279  0.108679
# ['palmas', 'palmas', 'palmas', 'palmas']            0.119573 -0.004307
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.002553  0.096084
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.009093  0.062578
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.034425  0.070620
# ['atendam', 'telefone', 'amor', 'deus']             0.027053  0.063675
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.002711  0.085825
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.007741  0.086803
#
#                                                      Vetor48   Vetor49
# Frase
# ['minuto', 'touro', 'ouro']                        -0.001749 -0.002428  \
# ['sim']                                            -0.064395 -0.025853
# ['queria', 'saber', 'banking', 'própria']          -0.068519 -0.027490
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.091760  0.027266
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat... -0.036452  0.003484
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.032271 -0.032976
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.056318  0.015074
# ['atendam', 'telefone', 'amor', 'deus']            -0.031798  0.055869
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.027396  0.024602
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.021195  0.024275
#
#                                                      Vetor50  sentimento
# Frase
# ['minuto', 'touro', 'ouro']                         0.263365           1
# ['sim']                                             0.185357           0
# ['queria', 'saber', 'banking', 'própria']           0.130485           1
# ['palmas', 'palmas', 'palmas', 'palmas']            0.144531           0
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.147662           1
# ...                                                      ...         ...
# ['excelente', 'explicação']                         0.160159           1
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.171040          -1
# ['atendam', 'telefone', 'amor', 'deus']             0.187216           1
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.160035           1
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.130305          -1
#
# [5667 rows x 51 columns]

# %% [markdown]
# #### Label encoding

# %% [markdown]
# O label encoding é feito para permitir com que o modelo interprete os diferentes resultados da váriavel alvo

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(df_cbow_NaN['sentimento'])
df_cbow_NaN['sentimento'] = le.transform(df_cbow_NaN['sentimento'])

# %% [markdown]
# ### Separando o dataset em treino e teste

# %%
target_cbow = df_cbow_NaN['sentimento']

# %%
features_cbow = df_cbow_NaN.iloc[:,0:50]
features_cbow
# Out:
#                                                       Vetor1    Vetor2
# Frase
# ['minuto', 'touro', 'ouro']                         0.194111 -0.086163  \
# ['sim']                                             0.109873 -0.062076
# ['queria', 'saber', 'banking', 'própria']           0.121342 -0.183903
# ['palmas', 'palmas', 'palmas', 'palmas']            0.215186 -0.092701
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.208002 -0.119283
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.156762 -0.134906
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.166784 -0.125591
# ['atendam', 'telefone', 'amor', 'deus']             0.136519 -0.113854
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.165214 -0.115387
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.162366 -0.135199
#
#                                                       Vetor3    Vetor4
# Frase
# ['minuto', 'touro', 'ouro']                         0.150576 -0.034733  \
# ['sim']                                             0.187268 -0.213734
# ['queria', 'saber', 'banking', 'própria']           0.268051 -0.031265
# ['palmas', 'palmas', 'palmas', 'palmas']            0.254579 -0.083714
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.219406 -0.040021
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.226852 -0.045667
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.187974 -0.061618
# ['atendam', 'telefone', 'amor', 'deus']             0.161438 -0.110917
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.168456 -0.092509
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.212927 -0.058698
#
#                                                       Vetor5    Vetor6
# Frase
# ['minuto', 'touro', 'ouro']                        -0.066786  0.122470  \
# ['sim']                                             0.046350  0.118452
# ['queria', 'saber', 'banking', 'própria']           0.003071  0.199323
# ['palmas', 'palmas', 'palmas', 'palmas']            0.099877  0.371233
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.008186  0.211272
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.064145  0.179836
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.001240  0.180365
# ['atendam', 'telefone', 'amor', 'deus']             0.034236  0.139376
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.001603  0.144674
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.015598  0.196113
#
#                                                       Vetor7    Vetor8
# Frase
# ['minuto', 'touro', 'ouro']                         0.027893  0.064956  \
# ['sim']                                            -0.025577 -0.149704
# ['queria', 'saber', 'banking', 'própria']          -0.008417  0.046410
# ['palmas', 'palmas', 'palmas', 'palmas']            0.050387 -0.127568
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.019965  0.025391
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.001532 -0.080106
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.004502  0.012454
# ['atendam', 'telefone', 'amor', 'deus']             0.029379 -0.063767
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.017509 -0.001471
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.006022  0.011471
#
#                                                       Vetor9   Vetor10  ...
# Frase                                                                   ...
# ['minuto', 'touro', 'ouro']                         0.005728  0.135925  ...  \
# ['sim']                                             0.143837  0.184814  ...
# ['queria', 'saber', 'banking', 'própria']           0.046311  0.069435  ...
# ['palmas', 'palmas', 'palmas', 'palmas']            0.118620  0.129699  ...
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.058953  0.116330  ...
# ...                                                      ...       ...  ...
# ['excelente', 'explicação']                        -0.059974  0.147371  ...
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.067296  0.108079  ...
# ['atendam', 'telefone', 'amor', 'deus']             0.037123  0.126380  ...
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.037615  0.111353  ...
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.036943  0.071967  ...
#
#                                                      Vetor41   Vetor42
# Frase
# ['minuto', 'touro', 'ouro']                        -0.161490  0.046650  \
# ['sim']                                            -0.314112  0.031963
# ['queria', 'saber', 'banking', 'própria']          -0.207068  0.029866
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.310632 -0.090724
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat... -0.277315 -0.018090
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.281259 -0.077624
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.215160  0.006491
# ['atendam', 'telefone', 'amor', 'deus']            -0.187910  0.000793
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.210521  0.012060
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.211146 -0.005936
#
#                                                      Vetor43   Vetor44
# Frase
# ['minuto', 'touro', 'ouro']                        -0.142142  0.131115  \
# ['sim']                                            -0.051879  0.235329
# ['queria', 'saber', 'banking', 'própria']          -0.076881  0.146361
# ['palmas', 'palmas', 'palmas', 'palmas']            0.021903  0.221911
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat... -0.062190  0.159715
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.021257  0.139206
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ... -0.059519  0.148439
# ['atendam', 'telefone', 'amor', 'deus']            -0.079159  0.139690
# ['grato', 'todo', 'esforço', 'rendeu', 'investi... -0.082116  0.126618
# ['morning', 'call', 'aparecendo', 'spotify', 'd... -0.051992  0.136300
#
#                                                      Vetor45   Vetor46
# Frase
# ['minuto', 'touro', 'ouro']                         0.063196  0.025213  \
# ['sim']                                            -0.005905  0.000182
# ['queria', 'saber', 'banking', 'própria']           0.077992 -0.022279
# ['palmas', 'palmas', 'palmas', 'palmas']            0.072890  0.119573
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.074844  0.002553
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.068294  0.009093
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.087409  0.034425
# ['atendam', 'telefone', 'amor', 'deus']             0.086531  0.027053
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.089894  0.002711
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.082029 -0.007741
#
#                                                      Vetor47   Vetor48
# Frase
# ['minuto', 'touro', 'ouro']                         0.094671 -0.001749  \
# ['sim']                                            -0.029570 -0.064395
# ['queria', 'saber', 'banking', 'própria']           0.108679 -0.068519
# ['palmas', 'palmas', 'palmas', 'palmas']           -0.004307 -0.091760
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.096084 -0.036452
# ...                                                      ...       ...
# ['excelente', 'explicação']                         0.062578 -0.032271
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.070620 -0.056318
# ['atendam', 'telefone', 'amor', 'deus']             0.063675 -0.031798
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.085825 -0.027396
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.086803 -0.021195
#
#                                                      Vetor49   Vetor50
# Frase
# ['minuto', 'touro', 'ouro']                        -0.002428  0.263365
# ['sim']                                            -0.025853  0.185357
# ['queria', 'saber', 'banking', 'própria']          -0.027490  0.130485
# ['palmas', 'palmas', 'palmas', 'palmas']            0.027266  0.144531
# ['vamos', 'ajudar', 'brasil', 'principal', 'cat...  0.003484  0.147662
# ...                                                      ...       ...
# ['excelente', 'explicação']                        -0.032976  0.160159
# ['porque', 'brg', 'tá', 'diminuído', 'limite', ...  0.015074  0.171040
# ['atendam', 'telefone', 'amor', 'deus']             0.055869  0.187216
# ['grato', 'todo', 'esforço', 'rendeu', 'investi...  0.024602  0.160035
# ['morning', 'call', 'aparecendo', 'spotify', 'd...  0.024275  0.130305
#
# [5667 rows x 50 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features_cbow, target_cbow, test_size=0.2, random_state=42)

# %% [markdown]
# ### Avaliação do modelo

# %%
# Naive Bayes

clf = GaussianNB()

# Treinando o modelo com os dados de teste 
clf = clf.fit(X_train,y_train.values.ravel())

# Prevendo a resposta do dataset
Y_pred = clf.predict(X_test)

print(classification_report(y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.82      0.65       387
#            1       0.78      0.60      0.67       447
#            2       0.34      0.22      0.27       300
#
#     accuracy                           0.57      1134
#    macro avg       0.55      0.55      0.53      1134
# weighted avg       0.58      0.57      0.56      1134

# %%
acc_score = accuracy_score(y_test, Y_pred)
format_output = "{:.2%}".format(acc_score)
print("A precisão foi de :",format_output)
# Out:
# A precisão foi de : 57.32%

# %% [markdown]
# ### Matriz de confusão

# %% [markdown]
# A matriz de confusão tem como objetivo, comparar as predições do modelo com o dataset real. De tal forma, nesse problema de multiclassificação é possível ter um panorama geral das respostas e se o modelo tem algum viés ou não.

# %%
# Criando uma matriz de confusão 
confusion_matrix_cbow = metrics.confusion_matrix(y_test, Y_pred)

# %%
# Criando a matriz e definindo nomes para colunas
cm_cbow = ConfusionMatrixDisplay(confusion_matrix_cbow, display_labels=['Negativo', 'Neutro', 'Positivo'])
cm_cbow.plot()
cm_cbow.ax_.set(
                title='Matriz de confusão Word2Vec CBOW', 
                xlabel='Sentimentos previstos', 
                ylabel='Sentimentos reais')
plt.show()
