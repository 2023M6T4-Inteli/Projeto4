# %%
import pandas as pd 
import numpy as np 
import spacy 
import gensim

# %%
df = pd.read_csv('../base/pre_processamento.csv', index_col=0)

# %%
df
# Out:
#                                           autor
# dataPublicada
# "2022-03-04 08:36:00"                lmviapiana  \
# "2022-03-03 21:10:00"              vanilson_dos
# "2022-03-03 20:54:00"               ricktolledo
# "2022-03-03 18:56:00"          claudiofalavinha
# "2022-03-03 16:11:00"     paularodrigues.invest
# ...                                         ...
# "2022-11-30 07:48:00"  perspectiveinvestimentos
# "2022-11-30 08:42:00"              marlenenelso
# "2022-11-30 11:27:00"            eduardocolares
# "2022-11-30 12:18:00"             jayipacderota
# "2022-11-30 14:27:00"                 bfmarilia
#
#                                                                    texto
# dataPublicada
# "2022-03-04 08:36:00"                               Minuto touro de ouro  \
# "2022-03-03 21:10:00"                                   @ricktolledo Sim
# "2022-03-03 20:54:00"  Queria saber se a Btg banking é a própria btg ...
# "2022-03-03 18:56:00"                                     @thaotinhasbfc
# "2022-03-03 16:11:00"                                               👏👏👏👏
# ...                                                                  ...
# "2022-11-30 07:48:00"                               Excelente explicação
# "2022-11-30 08:42:00"  Porque  o brg tá  diminuído  o limite  do cart...
# "2022-11-30 11:27:00"               Atendam o telefone pelo amor de Deus
# "2022-11-30 12:18:00"  Estou muito grato por todo o esforço que você ...
# "2022-11-30 14:27:00"  @btgpactual pq o morning call não está mais ap...
#
#                       sentimento tipoInteracao  anomalia
# dataPublicada
# "2022-03-04 08:36:00"   POSITIVE    comentário         0  \
# "2022-03-03 21:10:00"    NEUTRAL      resposta         0
# "2022-03-03 20:54:00"   POSITIVE    comentário         0
# "2022-03-03 18:56:00"    NEUTRAL    comentário         0
# "2022-03-03 16:11:00"    NEUTRAL    comentário         0
# ...                          ...           ...       ...
# "2022-11-30 07:48:00"   POSITIVE    comentário         0
# "2022-11-30 08:42:00"   NEGATIVE    comentário         1
# "2022-11-30 11:27:00"   POSITIVE    comentário         0
# "2022-11-30 12:18:00"   POSITIVE    comentário         1
# "2022-11-30 14:27:00"   NEGATIVE    comentário         0
#
#                        probabilidadeAnomalia
# dataPublicada
# "2022-03-04 08:36:00"                     38  \
# "2022-03-03 21:10:00"                     17
# "2022-03-03 20:54:00"                     20
# "2022-03-03 18:56:00"                     41
# "2022-03-03 16:11:00"                     15
# ...                                      ...
# "2022-11-30 07:48:00"                     15
# "2022-11-30 08:42:00"                     53
# "2022-11-30 11:27:00"                     28
# "2022-11-30 12:18:00"                     52
# "2022-11-30 14:27:00"                     28
#
#                                                                 linkPost
# dataPublicada
# "2022-03-04 08:36:00"  https://www.instagram.com/p/CapXhB5Lvas/#17977...  \
# "2022-03-03 21:10:00"  https://www.instagram.com/p/CapXhB5Lvas/#17842...
# "2022-03-03 20:54:00"  https://www.instagram.com/p/CapXhB5Lvas/#17935...
# "2022-03-03 18:56:00"  https://www.instagram.com/p/CapXhB5Lvas/#17942...
# "2022-03-03 16:11:00"  https://www.instagram.com/p/CaptWrtOT8U/#17943...
# ...                                                                  ...
# "2022-11-30 07:48:00"  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...
# "2022-11-30 08:42:00"  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...
# "2022-11-30 11:27:00"  https://www.instagram.com/p/CllkSBOuKlJ/#17960...
# "2022-11-30 12:18:00"  https://www.instagram.com/p/CllkSBOuKlJ/#17960...
# "2022-11-30 14:27:00"  https://www.instagram.com/p/CllkSBOuKlJ/#17975...
#
#                        processado  contemHyperlink
# dataPublicada
# "2022-03-04 08:36:00"           0                0  \
# "2022-03-03 21:10:00"           0                0
# "2022-03-03 20:54:00"           0                0
# "2022-03-03 18:56:00"           0                0
# "2022-03-03 16:11:00"           0                0
# ...                           ...              ...
# "2022-11-30 07:48:00"           0                0
# "2022-11-30 08:42:00"           0                0
# "2022-11-30 11:27:00"           0                0
# "2022-11-30 12:18:00"           0                0
# "2022-11-30 14:27:00"           0                0
#
#                                                          texto_e_palavra
# dataPublicada
# "2022-03-04 08:36:00"                               Minuto touro de ouro  \
# "2022-03-03 21:10:00"                                   @ricktolledo Sim
# "2022-03-03 20:54:00"  Queria saber se a Btg banking é a própria btg ...
# "2022-03-03 18:56:00"                                     @thaotinhasbfc
# "2022-03-03 16:11:00"                       palmas palmas palmas palmas
# ...                                                                  ...
# "2022-11-30 07:48:00"                               Excelente explicação
# "2022-11-30 08:42:00"  Porque  o brg tá  diminuído  o limite  do cart...
# "2022-11-30 11:27:00"               Atendam o telefone pelo amor de Deus
# "2022-11-30 12:18:00"  Estou muito grato por todo o esforço que você ...
# "2022-11-30 14:27:00"  @btgpactual pq o morning call não está mais ap...
#
#                                                         texto_tokenizado
# dataPublicada
# "2022-03-04 08:36:00"                        ['minuto', 'touro', 'ouro']
# "2022-03-03 21:10:00"                                            ['sim']
# "2022-03-03 20:54:00"          ['queria', 'saber', 'banking', 'própria']
# "2022-03-03 18:56:00"                                                 []
# "2022-03-03 16:11:00"           ['palmas', 'palmas', 'palmas', 'palmas']
# ...                                                                  ...
# "2022-11-30 07:48:00"                        ['excelente', 'explicação']
# "2022-11-30 08:42:00"  ['porque', 'brg', 'tá', 'diminuído', 'limite',...
# "2022-11-30 11:27:00"            ['atendam', 'telefone', 'amor', 'deus']
# "2022-11-30 12:18:00"  ['grato', 'todo', 'esforço', 'rendeu', 'invest...
# "2022-11-30 14:27:00"  ['morning', 'call', 'aparecendo', 'spotify', '...
#
# [6356 rows x 11 columns]

# %% [markdown]
# *1* - Baixe o modelo treinado de word embedding "CBOW 50 dimensões" do site do NILC (http://nilc.icmc.usp.br/nilc/index.php/repositorio-de-word-embeddings-do-nilc)
#
# 2 - Coloque o arquivo extraído "cbow_s50.txt" na pasta com o nome "base" do repositório

# %%
cbow = '../base/cbow_s50.txt'

# %%
from scipy.spatial.distance import cosine

from gensim.models import KeyedVectors

model_cbow = KeyedVectors.load_word2vec_format(cbow)

# %%
# Testando o word2vec
wordvec_word1 = model_cbow['banco']

wordvec_word1
# Out:
# array([ 1.81041e-01,  1.07700e-01, -1.04667e-01,  2.43361e-01,
#         6.06380e-02,  3.92829e-01, -3.33944e-01, -3.81778e-01,
#         1.42200e-01,  8.59360e-02, -1.16615e-01,  3.95722e-01,
#        -6.12684e-01, -7.68980e-02,  3.34396e-01,  8.11270e-02,
#        -5.17700e-02, -3.21950e-01, -6.91509e-01, -3.31210e-01,
#        -5.43213e-01,  6.09881e-01,  2.43700e-01,  3.73240e-02,
#         1.16518e-01,  1.78859e-01, -3.78839e-01,  1.27430e-01,
#         1.94497e-01,  7.32000e-04,  3.14395e-01, -2.04550e-01,
#         5.34431e-01, -5.55100e-03,  3.52343e-01, -4.92000e-02,
#        -1.38384e-01,  2.31630e-02, -3.40013e-01,  5.00201e-01,
#        -1.14170e-02, -1.29925e-01, -6.12800e-03, -1.80481e-01,
#         1.99391e-01,  1.37645e-01, -7.66434e-01, -2.26784e-01,
#        -6.16110e-02,  9.05920e-02], dtype=float32)

# %%
# Substituindo todos os elementos vazios da coluna texto_tokenizado por NaN
df['texto_tokenizado'].replace('[]', np.nan, inplace=True)

# %%
df
# Out:
#                                           autor
# dataPublicada
# "2022-03-04 08:36:00"                lmviapiana  \
# "2022-03-03 21:10:00"              vanilson_dos
# "2022-03-03 20:54:00"               ricktolledo
# "2022-03-03 18:56:00"          claudiofalavinha
# "2022-03-03 16:11:00"     paularodrigues.invest
# ...                                         ...
# "2022-11-30 07:48:00"  perspectiveinvestimentos
# "2022-11-30 08:42:00"              marlenenelso
# "2022-11-30 11:27:00"            eduardocolares
# "2022-11-30 12:18:00"             jayipacderota
# "2022-11-30 14:27:00"                 bfmarilia
#
#                                                                    texto
# dataPublicada
# "2022-03-04 08:36:00"                               Minuto touro de ouro  \
# "2022-03-03 21:10:00"                                   @ricktolledo Sim
# "2022-03-03 20:54:00"  Queria saber se a Btg banking é a própria btg ...
# "2022-03-03 18:56:00"                                     @thaotinhasbfc
# "2022-03-03 16:11:00"                                               👏👏👏👏
# ...                                                                  ...
# "2022-11-30 07:48:00"                               Excelente explicação
# "2022-11-30 08:42:00"  Porque  o brg tá  diminuído  o limite  do cart...
# "2022-11-30 11:27:00"               Atendam o telefone pelo amor de Deus
# "2022-11-30 12:18:00"  Estou muito grato por todo o esforço que você ...
# "2022-11-30 14:27:00"  @btgpactual pq o morning call não está mais ap...
#
#                       sentimento tipoInteracao  anomalia
# dataPublicada
# "2022-03-04 08:36:00"   POSITIVE    comentário         0  \
# "2022-03-03 21:10:00"    NEUTRAL      resposta         0
# "2022-03-03 20:54:00"   POSITIVE    comentário         0
# "2022-03-03 18:56:00"    NEUTRAL    comentário         0
# "2022-03-03 16:11:00"    NEUTRAL    comentário         0
# ...                          ...           ...       ...
# "2022-11-30 07:48:00"   POSITIVE    comentário         0
# "2022-11-30 08:42:00"   NEGATIVE    comentário         1
# "2022-11-30 11:27:00"   POSITIVE    comentário         0
# "2022-11-30 12:18:00"   POSITIVE    comentário         1
# "2022-11-30 14:27:00"   NEGATIVE    comentário         0
#
#                        probabilidadeAnomalia
# dataPublicada
# "2022-03-04 08:36:00"                     38  \
# "2022-03-03 21:10:00"                     17
# "2022-03-03 20:54:00"                     20
# "2022-03-03 18:56:00"                     41
# "2022-03-03 16:11:00"                     15
# ...                                      ...
# "2022-11-30 07:48:00"                     15
# "2022-11-30 08:42:00"                     53
# "2022-11-30 11:27:00"                     28
# "2022-11-30 12:18:00"                     52
# "2022-11-30 14:27:00"                     28
#
#                                                                 linkPost
# dataPublicada
# "2022-03-04 08:36:00"  https://www.instagram.com/p/CapXhB5Lvas/#17977...  \
# "2022-03-03 21:10:00"  https://www.instagram.com/p/CapXhB5Lvas/#17842...
# "2022-03-03 20:54:00"  https://www.instagram.com/p/CapXhB5Lvas/#17935...
# "2022-03-03 18:56:00"  https://www.instagram.com/p/CapXhB5Lvas/#17942...
# "2022-03-03 16:11:00"  https://www.instagram.com/p/CaptWrtOT8U/#17943...
# ...                                                                  ...
# "2022-11-30 07:48:00"  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...
# "2022-11-30 08:42:00"  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...
# "2022-11-30 11:27:00"  https://www.instagram.com/p/CllkSBOuKlJ/#17960...
# "2022-11-30 12:18:00"  https://www.instagram.com/p/CllkSBOuKlJ/#17960...
# "2022-11-30 14:27:00"  https://www.instagram.com/p/CllkSBOuKlJ/#17975...
#
#                        processado  contemHyperlink
# dataPublicada
# "2022-03-04 08:36:00"           0                0  \
# "2022-03-03 21:10:00"           0                0
# "2022-03-03 20:54:00"           0                0
# "2022-03-03 18:56:00"           0                0
# "2022-03-03 16:11:00"           0                0
# ...                           ...              ...
# "2022-11-30 07:48:00"           0                0
# "2022-11-30 08:42:00"           0                0
# "2022-11-30 11:27:00"           0                0
# "2022-11-30 12:18:00"           0                0
# "2022-11-30 14:27:00"           0                0
#
#                                                          texto_e_palavra
# dataPublicada
# "2022-03-04 08:36:00"                               Minuto touro de ouro  \
# "2022-03-03 21:10:00"                                   @ricktolledo Sim
# "2022-03-03 20:54:00"  Queria saber se a Btg banking é a própria btg ...
# "2022-03-03 18:56:00"                                     @thaotinhasbfc
# "2022-03-03 16:11:00"                       palmas palmas palmas palmas
# ...                                                                  ...
# "2022-11-30 07:48:00"                               Excelente explicação
# "2022-11-30 08:42:00"  Porque  o brg tá  diminuído  o limite  do cart...
# "2022-11-30 11:27:00"               Atendam o telefone pelo amor de Deus
# "2022-11-30 12:18:00"  Estou muito grato por todo o esforço que você ...
# "2022-11-30 14:27:00"  @btgpactual pq o morning call não está mais ap...
#
#                                                         texto_tokenizado
# dataPublicada
# "2022-03-04 08:36:00"                        ['minuto', 'touro', 'ouro']
# "2022-03-03 21:10:00"                                            ['sim']
# "2022-03-03 20:54:00"          ['queria', 'saber', 'banking', 'própria']
# "2022-03-03 18:56:00"                                                 []
# "2022-03-03 16:11:00"           ['palmas', 'palmas', 'palmas', 'palmas']
# ...                                                                  ...
# "2022-11-30 07:48:00"                        ['excelente', 'explicação']
# "2022-11-30 08:42:00"  ['porque', 'brg', 'tá', 'diminuído', 'limite',...
# "2022-11-30 11:27:00"            ['atendam', 'telefone', 'amor', 'deus']
# "2022-11-30 12:18:00"  ['grato', 'todo', 'esforço', 'rendeu', 'invest...
# "2022-11-30 14:27:00"  ['morning', 'call', 'aparecendo', 'spotify', '...
#
# [6356 rows x 11 columns]

# %%
# Removendo todos os NaN
df = df.dropna()
df
# Out:
#                                           autor
# dataPublicada
# "2022-03-04 08:36:00"                lmviapiana  \
# "2022-03-03 21:10:00"              vanilson_dos
# "2022-03-03 20:54:00"               ricktolledo
# "2022-03-03 16:11:00"     paularodrigues.invest
# "2022-03-03 15:35:00"             rafael_miller
# ...                                         ...
# "2022-11-30 07:48:00"  perspectiveinvestimentos
# "2022-11-30 08:42:00"              marlenenelso
# "2022-11-30 11:27:00"            eduardocolares
# "2022-11-30 12:18:00"             jayipacderota
# "2022-11-30 14:27:00"                 bfmarilia
#
#                                                                    texto
# dataPublicada
# "2022-03-04 08:36:00"                               Minuto touro de ouro  \
# "2022-03-03 21:10:00"                                   @ricktolledo Sim
# "2022-03-03 20:54:00"  Queria saber se a Btg banking é a própria btg ...
# "2022-03-03 16:11:00"                                               👏👏👏👏
# "2022-03-03 15:35:00"  Vamos ajudar o Brasil na principal categoria d...
# ...                                                                  ...
# "2022-11-30 07:48:00"                               Excelente explicação
# "2022-11-30 08:42:00"  Porque  o brg tá  diminuído  o limite  do cart...
# "2022-11-30 11:27:00"               Atendam o telefone pelo amor de Deus
# "2022-11-30 12:18:00"  Estou muito grato por todo o esforço que você ...
# "2022-11-30 14:27:00"  @btgpactual pq o morning call não está mais ap...
#
#                       sentimento tipoInteracao  anomalia
# dataPublicada
# "2022-03-04 08:36:00"   POSITIVE    comentário         0  \
# "2022-03-03 21:10:00"    NEUTRAL      resposta         0
# "2022-03-03 20:54:00"   POSITIVE    comentário         0
# "2022-03-03 16:11:00"    NEUTRAL    comentário         0
# "2022-03-03 15:35:00"   POSITIVE    comentário         0
# ...                          ...           ...       ...
# "2022-11-30 07:48:00"   POSITIVE    comentário         0
# "2022-11-30 08:42:00"   NEGATIVE    comentário         1
# "2022-11-30 11:27:00"   POSITIVE    comentário         0
# "2022-11-30 12:18:00"   POSITIVE    comentário         1
# "2022-11-30 14:27:00"   NEGATIVE    comentário         0
#
#                        probabilidadeAnomalia
# dataPublicada
# "2022-03-04 08:36:00"                     38  \
# "2022-03-03 21:10:00"                     17
# "2022-03-03 20:54:00"                     20
# "2022-03-03 16:11:00"                     15
# "2022-03-03 15:35:00"                     41
# ...                                      ...
# "2022-11-30 07:48:00"                     15
# "2022-11-30 08:42:00"                     53
# "2022-11-30 11:27:00"                     28
# "2022-11-30 12:18:00"                     52
# "2022-11-30 14:27:00"                     28
#
#                                                                 linkPost
# dataPublicada
# "2022-03-04 08:36:00"  https://www.instagram.com/p/CapXhB5Lvas/#17977...  \
# "2022-03-03 21:10:00"  https://www.instagram.com/p/CapXhB5Lvas/#17842...
# "2022-03-03 20:54:00"  https://www.instagram.com/p/CapXhB5Lvas/#17935...
# "2022-03-03 16:11:00"  https://www.instagram.com/p/CaptWrtOT8U/#17943...
# "2022-03-03 15:35:00"  https://www.instagram.com/p/CapoqJ3Ne7a/#17972...
# ...                                                                  ...
# "2022-11-30 07:48:00"  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...
# "2022-11-30 08:42:00"  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...
# "2022-11-30 11:27:00"  https://www.instagram.com/p/CllkSBOuKlJ/#17960...
# "2022-11-30 12:18:00"  https://www.instagram.com/p/CllkSBOuKlJ/#17960...
# "2022-11-30 14:27:00"  https://www.instagram.com/p/CllkSBOuKlJ/#17975...
#
#                        processado  contemHyperlink
# dataPublicada
# "2022-03-04 08:36:00"           0                0  \
# "2022-03-03 21:10:00"           0                0
# "2022-03-03 20:54:00"           0                0
# "2022-03-03 16:11:00"           0                0
# "2022-03-03 15:35:00"           0                0
# ...                           ...              ...
# "2022-11-30 07:48:00"           0                0
# "2022-11-30 08:42:00"           0                0
# "2022-11-30 11:27:00"           0                0
# "2022-11-30 12:18:00"           0                0
# "2022-11-30 14:27:00"           0                0
#
#                                                          texto_e_palavra
# dataPublicada
# "2022-03-04 08:36:00"                               Minuto touro de ouro  \
# "2022-03-03 21:10:00"                                   @ricktolledo Sim
# "2022-03-03 20:54:00"  Queria saber se a Btg banking é a própria btg ...
# "2022-03-03 16:11:00"                       palmas palmas palmas palmas
# "2022-03-03 15:35:00"  Vamos ajudar o Brasil na principal categoria d...
# ...                                                                  ...
# "2022-11-30 07:48:00"                               Excelente explicação
# "2022-11-30 08:42:00"  Porque  o brg tá  diminuído  o limite  do cart...
# "2022-11-30 11:27:00"               Atendam o telefone pelo amor de Deus
# "2022-11-30 12:18:00"  Estou muito grato por todo o esforço que você ...
# "2022-11-30 14:27:00"  @btgpactual pq o morning call não está mais ap...
#
#                                                         texto_tokenizado
# dataPublicada
# "2022-03-04 08:36:00"                        ['minuto', 'touro', 'ouro']
# "2022-03-03 21:10:00"                                            ['sim']
# "2022-03-03 20:54:00"          ['queria', 'saber', 'banking', 'própria']
# "2022-03-03 16:11:00"           ['palmas', 'palmas', 'palmas', 'palmas']
# "2022-03-03 15:35:00"  ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                                  ...
# "2022-11-30 07:48:00"                        ['excelente', 'explicação']
# "2022-11-30 08:42:00"  ['porque', 'brg', 'tá', 'diminuído', 'limite',...
# "2022-11-30 11:27:00"            ['atendam', 'telefone', 'amor', 'deus']
# "2022-11-30 12:18:00"  ['grato', 'todo', 'esforço', 'rendeu', 'invest...
# "2022-11-30 14:27:00"  ['morning', 'call', 'aparecendo', 'spotify', '...
#
# [5667 rows x 11 columns]

# %%
def create_sentence_vector(model, cleaned_df):
    sentence_table = []
    for sentence in cleaned_df['texto_tokenizado']:
        word_vectors = [model[word] for word in sentence if word in model]
        if len(word_vectors) > 0:
            sentence_vector = sum(word_vectors) / len(word_vectors)
        else:
            sentence_vector = [None] * 100  # Cria uma lista de 100 elementos None
        sentence_table.append((sentence, *sentence_vector[:50]))  # Adiciona apenas os primeiros 50 elementos do vetor

    column_labels = ['Frase']
    for i in range(50):
        column_labels.append(f'Vetor{i+1}')
    df_vec = pd.DataFrame(sentence_table, columns=column_labels)

    cleaned_df["sentimentoNumerico"] = cleaned_df["sentimento"].replace({'NEGATIVE': -1, 'POSITIVE': 1, 'NEUTRAL': 0})

    # Definir o índice do DataFrame df_vec como o mesmo índice de df_processada['sentimentoNumerico']
    df_vec.set_index(cleaned_df["sentimentoNumerico"].index, inplace=True)

    df_vec['sentimento'] = cleaned_df["sentimentoNumerico"]
    df_vec = df_vec.dropna()

    return df_vec

# %%
df_vec = create_sentence_vector(model_cbow, df)
df_vec
# Out:
#                                                                    Frase
# dataPublicada
# "2022-03-04 08:36:00"                        ['minuto', 'touro', 'ouro']  \
# "2022-03-03 21:10:00"                                            ['sim']
# "2022-03-03 20:54:00"          ['queria', 'saber', 'banking', 'própria']
# "2022-03-03 16:11:00"           ['palmas', 'palmas', 'palmas', 'palmas']
# "2022-03-03 15:35:00"  ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                                  ...
# "2022-11-30 07:48:00"                        ['excelente', 'explicação']
# "2022-11-30 08:42:00"  ['porque', 'brg', 'tá', 'diminuído', 'limite',...
# "2022-11-30 11:27:00"            ['atendam', 'telefone', 'amor', 'deus']
# "2022-11-30 12:18:00"  ['grato', 'todo', 'esforço', 'rendeu', 'invest...
# "2022-11-30 14:27:00"  ['morning', 'call', 'aparecendo', 'spotify', '...
#
#                          Vetor1    Vetor2    Vetor3    Vetor4    Vetor5
# dataPublicada
# "2022-03-04 08:36:00"  0.194111 -0.086163  0.150576 -0.034733 -0.066786  \
# "2022-03-03 21:10:00"  0.109873 -0.062076  0.187268 -0.213734  0.046350
# "2022-03-03 20:54:00"  0.121342 -0.183903  0.268051 -0.031265  0.003071
# "2022-03-03 16:11:00"  0.215186 -0.092701  0.254579 -0.083714  0.099877
# "2022-03-03 15:35:00"  0.208002 -0.119283  0.219406 -0.040021  0.008186
# ...                         ...       ...       ...       ...       ...
# "2022-11-30 07:48:00"  0.156762 -0.134906  0.226852 -0.045667  0.064145
# "2022-11-30 08:42:00"  0.166784 -0.125591  0.187974 -0.061618  0.001240
# "2022-11-30 11:27:00"  0.136519 -0.113854  0.161438 -0.110917  0.034236
# "2022-11-30 12:18:00"  0.165214 -0.115387  0.168456 -0.092509 -0.001603
# "2022-11-30 14:27:00"  0.162366 -0.135199  0.212927 -0.058698  0.015598
#
#                          Vetor6    Vetor7    Vetor8    Vetor9  ...   Vetor42
# dataPublicada                                                  ...
# "2022-03-04 08:36:00"  0.122470  0.027893  0.064956  0.005728  ...  0.046650  \
# "2022-03-03 21:10:00"  0.118452 -0.025577 -0.149704  0.143837  ...  0.031963
# "2022-03-03 20:54:00"  0.199323 -0.008417  0.046410  0.046311  ...  0.029866
# "2022-03-03 16:11:00"  0.371233  0.050387 -0.127568  0.118620  ... -0.090724
# "2022-03-03 15:35:00"  0.211272  0.019965  0.025391  0.058953  ... -0.018090
# ...                         ...       ...       ...       ...  ...       ...
# "2022-11-30 07:48:00"  0.179836  0.001532 -0.080106 -0.059974  ... -0.077624
# "2022-11-30 08:42:00"  0.180365  0.004502  0.012454  0.067296  ...  0.006491
# "2022-11-30 11:27:00"  0.139376  0.029379 -0.063767  0.037123  ...  0.000793
# "2022-11-30 12:18:00"  0.144674  0.017509 -0.001471  0.037615  ...  0.012060
# "2022-11-30 14:27:00"  0.196113 -0.006022  0.011471  0.036943  ... -0.005936
#
#                         Vetor43   Vetor44   Vetor45   Vetor46   Vetor47
# dataPublicada
# "2022-03-04 08:36:00" -0.142142  0.131115  0.063196  0.025213  0.094671  \
# "2022-03-03 21:10:00" -0.051879  0.235329 -0.005905  0.000182 -0.029570
# "2022-03-03 20:54:00" -0.076881  0.146361  0.077992 -0.022279  0.108679
# "2022-03-03 16:11:00"  0.021903  0.221911  0.072890  0.119573 -0.004307
# "2022-03-03 15:35:00" -0.062190  0.159715  0.074844  0.002553  0.096084
# ...                         ...       ...       ...       ...       ...
# "2022-11-30 07:48:00"  0.021257  0.139206  0.068294  0.009093  0.062578
# "2022-11-30 08:42:00" -0.059519  0.148439  0.087409  0.034425  0.070620
# "2022-11-30 11:27:00" -0.079159  0.139690  0.086531  0.027053  0.063675
# "2022-11-30 12:18:00" -0.082116  0.126618  0.089894  0.002711  0.085825
# "2022-11-30 14:27:00" -0.051992  0.136300  0.082029 -0.007741  0.086803
#
#                         Vetor48   Vetor49   Vetor50  sentimento
# dataPublicada
# "2022-03-04 08:36:00" -0.001749 -0.002428  0.263365           1
# "2022-03-03 21:10:00" -0.064395 -0.025853  0.185357           0
# "2022-03-03 20:54:00" -0.068519 -0.027490  0.130485           1
# "2022-03-03 16:11:00" -0.091760  0.027266  0.144531           0
# "2022-03-03 15:35:00" -0.036452  0.003484  0.147662           1
# ...                         ...       ...       ...         ...
# "2022-11-30 07:48:00" -0.032271 -0.032976  0.160159           1
# "2022-11-30 08:42:00" -0.056318  0.015074  0.171040          -1
# "2022-11-30 11:27:00" -0.031798  0.055869  0.187216           1
# "2022-11-30 12:18:00" -0.027396  0.024602  0.160035           1
# "2022-11-30 14:27:00" -0.021195  0.024275  0.130305          -1
#
# [5667 rows x 52 columns]

# %%
# Exportando o csv com o resultado da aplicação do word2vec com os vetores pré treinados 
df_vec.to_csv('..\\output\\word2vec_cbow.csv',encoding='utf-8', index=False, header=True, )
