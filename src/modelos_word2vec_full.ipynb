# %% [markdown]
# ### Word2Vec
#
# Neste notebook serão feitas duas representações do modelo word2vec uma com uma base pré treinada e outra utilizando o corpus como base

# %% [markdown]
# #### Importando as bibliotecas

# %%
import pandas as pd 
import numpy as np 
import spacy 
import gensim
from gensim import models
from gensim.models import Word2Vec, KeyedVectors
from scipy.spatial.distance import cosine

# %% [markdown]
# ### Word2Vec base pré processada

# %%
# Abrindo a base já pré-processada 
df = pd.read_csv('../output/sentimento_revisto.csv')
df
# Out:
#                          autor
# 0                   lmviapiana  \
# 1                 vanilson_dos
# 2                  ricktolledo
# 3        paularodrigues.invest
# 4                rafael_miller
# ...                        ...
# 5662  perspectiveinvestimentos
# 5663              marlenenelso
# 5664            eduardocolares
# 5665             jayipacderota
# 5666                 bfmarilia
#
#                                                   texto sentimento
# 0                                  Minuto touro de ouro   POSITIVE  \
# 1                                      @ricktolledo Sim    NEUTRAL
# 2     Queria saber se a Btg banking é a própria btg ...   POSITIVE
# 3                                                  👏👏👏👏    NEUTRAL
# 4     Vamos ajudar o Brasil na principal categoria d...   POSITIVE
# ...                                                 ...        ...
# 5662                               Excelente explicação   POSITIVE
# 5663  Porque  o brg tá  diminuído  o limite  do cart...   NEGATIVE
# 5664               Atendam o telefone pelo amor de Deus   POSITIVE
# 5665  Estou muito grato por todo o esforço que você ...   POSITIVE
# 5666  @btgpactual pq o morning call não está mais ap...   NEGATIVE
#
#      tipoInteracao  anomalia  probabilidadeAnomalia
# 0       comentário         0                     38  \
# 1         resposta         0                     17
# 2       comentário         0                     20
# 3       comentário         0                     15
# 4       comentário         0                     41
# ...            ...       ...                    ...
# 5662    comentário         0                     15
# 5663    comentário         1                     53
# 5664    comentário         0                     28
# 5665    comentário         1                     52
# 5666    comentário         0                     28
#
#                                                linkPost  processado
# 0     https://www.instagram.com/p/CapXhB5Lvas/#17977...           0  \
# 1     https://www.instagram.com/p/CapXhB5Lvas/#17842...           0
# 2     https://www.instagram.com/p/CapXhB5Lvas/#17935...           0
# 3     https://www.instagram.com/p/CaptWrtOT8U/#17943...           0
# 4     https://www.instagram.com/p/CapoqJ3Ne7a/#17972...           0
# ...                                                 ...         ...
# 5662  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...           0
# 5663  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...           0
# 5664  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5665  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5666  https://www.instagram.com/p/CllkSBOuKlJ/#17975...           0
#
#       contemHyperlink                                    texto_e_palavra
# 0                   0                               Minuto touro de ouro  \
# 1                   0                                   @ricktolledo Sim
# 2                   0  Queria saber se a Btg banking é a própria btg ...
# 3                   0                       palmas palmas palmas palmas
# 4                   0  Vamos ajudar o Brasil na principal categoria d...
# ...               ...                                                ...
# 5662                0                               Excelente explicação
# 5663                0  Porque  o brg tá  diminuído  o limite  do cart...
# 5664                0               Atendam o telefone pelo amor de Deus
# 5665                0  Estou muito grato por todo o esforço que você ...
# 5666                0  @btgpactual pq o morning call não está mais ap...
#
#                                        texto_tokenizado  sentimento_revisto
# 0                           ['minuto', 'touro', 'ouro']                   1  \
# 1                                               ['sim']                   0
# 2             ['queria', 'saber', 'banking', 'própria']                   1
# 3              ['palmas', 'palmas', 'palmas', 'palmas']                   1
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...                   1
# ...                                                 ...                 ...
# 5662                        ['excelente', 'explicação']                  -1
# 5663  ['porque', 'brg', 'tá', 'diminuído', 'limite',...                  -1
# 5664            ['atendam', 'telefone', 'amor', 'deus']                  -1
# 5665  ['grato', 'todo', 'esforço', 'rendeu', 'invest...                  -1
# 5666  ['morning', 'call', 'aparecendo', 'spotify', '...                  -1
#
#                                       texto_tokenizado2
# 0                           ['minuto', 'touro', 'ouro']
# 1                                               ['sim']
# 2                        ['queria', 'saber', 'banking']
# 3              ['palmas', 'palmas', 'palmas', 'palmas']
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                 ...
# 5662                        ['excelente', 'explicação']
# 5663  ['tá', 'diminuído', 'limite', 'do', 'cartão', ...
# 5664            ['atendam', 'telefone', 'amor', 'deus']
# 5665  ['muito', 'grato', 'todo', 'esforço', 'você', ...
# 5666  ['morning', 'call', 'não', 'mais', 'aparecendo...
#
# [5667 rows x 13 columns]

# %% [markdown]
# *1* - Baixe o modelo treinado de word embedding "CBOW 50 dimensões" do site do NILC (http://nilc.icmc.usp.br/nilc/index.php/repositorio-de-word-embeddings-do-nilc)
#
# 2 - Coloque o arquivo extraído "cbow_s50.txt" na pasta com o nome "base" do repositório

# %%
# Coloque o arquivo nesse caminho
cbow = '../base/cbow_s50.txt'

# %%
# Carregando o modelo

model_cbow = KeyedVectors.load_word2vec_format(cbow)

# %%
# Testando o word2vec
wordvec_word1 = model_cbow['banco']

wordvec_word1
# Out:
# array([ 1.81041e-01,  1.07700e-01, -1.04667e-01,  2.43361e-01,
#         6.06380e-02,  3.92829e-01, -3.33944e-01, -3.81778e-01,
#         1.42200e-01,  8.59360e-02, -1.16615e-01,  3.95722e-01,
#        -6.12684e-01, -7.68980e-02,  3.34396e-01,  8.11270e-02,
#        -5.17700e-02, -3.21950e-01, -6.91509e-01, -3.31210e-01,
#        -5.43213e-01,  6.09881e-01,  2.43700e-01,  3.73240e-02,
#         1.16518e-01,  1.78859e-01, -3.78839e-01,  1.27430e-01,
#         1.94497e-01,  7.32000e-04,  3.14395e-01, -2.04550e-01,
#         5.34431e-01, -5.55100e-03,  3.52343e-01, -4.92000e-02,
#        -1.38384e-01,  2.31630e-02, -3.40013e-01,  5.00201e-01,
#        -1.14170e-02, -1.29925e-01, -6.12800e-03, -1.80481e-01,
#         1.99391e-01,  1.37645e-01, -7.66434e-01, -2.26784e-01,
#        -6.16110e-02,  9.05920e-02], dtype=float32)

# %%
df
# Out:
#                          autor
# 0                   lmviapiana  \
# 1                 vanilson_dos
# 2                  ricktolledo
# 3        paularodrigues.invest
# 4                rafael_miller
# ...                        ...
# 5662  perspectiveinvestimentos
# 5663              marlenenelso
# 5664            eduardocolares
# 5665             jayipacderota
# 5666                 bfmarilia
#
#                                                   texto sentimento
# 0                                  Minuto touro de ouro   POSITIVE  \
# 1                                      @ricktolledo Sim    NEUTRAL
# 2     Queria saber se a Btg banking é a própria btg ...   POSITIVE
# 3                                                  👏👏👏👏    NEUTRAL
# 4     Vamos ajudar o Brasil na principal categoria d...   POSITIVE
# ...                                                 ...        ...
# 5662                               Excelente explicação   POSITIVE
# 5663  Porque  o brg tá  diminuído  o limite  do cart...   NEGATIVE
# 5664               Atendam o telefone pelo amor de Deus   POSITIVE
# 5665  Estou muito grato por todo o esforço que você ...   POSITIVE
# 5666  @btgpactual pq o morning call não está mais ap...   NEGATIVE
#
#      tipoInteracao  anomalia  probabilidadeAnomalia
# 0       comentário         0                     38  \
# 1         resposta         0                     17
# 2       comentário         0                     20
# 3       comentário         0                     15
# 4       comentário         0                     41
# ...            ...       ...                    ...
# 5662    comentário         0                     15
# 5663    comentário         1                     53
# 5664    comentário         0                     28
# 5665    comentário         1                     52
# 5666    comentário         0                     28
#
#                                                linkPost  processado
# 0     https://www.instagram.com/p/CapXhB5Lvas/#17977...           0  \
# 1     https://www.instagram.com/p/CapXhB5Lvas/#17842...           0
# 2     https://www.instagram.com/p/CapXhB5Lvas/#17935...           0
# 3     https://www.instagram.com/p/CaptWrtOT8U/#17943...           0
# 4     https://www.instagram.com/p/CapoqJ3Ne7a/#17972...           0
# ...                                                 ...         ...
# 5662  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...           0
# 5663  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...           0
# 5664  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5665  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5666  https://www.instagram.com/p/CllkSBOuKlJ/#17975...           0
#
#       contemHyperlink                                    texto_e_palavra
# 0                   0                               Minuto touro de ouro  \
# 1                   0                                   @ricktolledo Sim
# 2                   0  Queria saber se a Btg banking é a própria btg ...
# 3                   0                       palmas palmas palmas palmas
# 4                   0  Vamos ajudar o Brasil na principal categoria d...
# ...               ...                                                ...
# 5662                0                               Excelente explicação
# 5663                0  Porque  o brg tá  diminuído  o limite  do cart...
# 5664                0               Atendam o telefone pelo amor de Deus
# 5665                0  Estou muito grato por todo o esforço que você ...
# 5666                0  @btgpactual pq o morning call não está mais ap...
#
#                                        texto_tokenizado  sentimento_revisto
# 0                           ['minuto', 'touro', 'ouro']                   1  \
# 1                                               ['sim']                   0
# 2             ['queria', 'saber', 'banking', 'própria']                   1
# 3              ['palmas', 'palmas', 'palmas', 'palmas']                   1
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...                   1
# ...                                                 ...                 ...
# 5662                        ['excelente', 'explicação']                  -1
# 5663  ['porque', 'brg', 'tá', 'diminuído', 'limite',...                  -1
# 5664            ['atendam', 'telefone', 'amor', 'deus']                  -1
# 5665  ['grato', 'todo', 'esforço', 'rendeu', 'invest...                  -1
# 5666  ['morning', 'call', 'aparecendo', 'spotify', '...                  -1
#
#                                       texto_tokenizado2
# 0                           ['minuto', 'touro', 'ouro']
# 1                                               ['sim']
# 2                        ['queria', 'saber', 'banking']
# 3              ['palmas', 'palmas', 'palmas', 'palmas']
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                 ...
# 5662                        ['excelente', 'explicação']
# 5663  ['tá', 'diminuído', 'limite', 'do', 'cartão', ...
# 5664            ['atendam', 'telefone', 'amor', 'deus']
# 5665  ['muito', 'grato', 'todo', 'esforço', 'você', ...
# 5666  ['morning', 'call', 'não', 'mais', 'aparecendo...
#
# [5667 rows x 13 columns]

# %%
# Função que cria as colunas com o modelo já pré treinado
def create_sentence_vector(model, cleaned_df):
    sentence_table = []
    for sentence in cleaned_df['texto_tokenizado2']:
        word_vectors = [model[word] for word in sentence if word in model]
        if len(word_vectors) > 0:
            sentence_vector = sum(word_vectors) / len(word_vectors)
        else:
            sentence_vector = [None] * 100  # Cria uma lista de 100 elementos None
        sentence_table.append((sentence, *sentence_vector[:50]))  # Adiciona apenas os primeiros 50 elementos do vetor

    column_labels = ['Frase']
    for i in range(50):
        column_labels.append(f'Vetor{i+1}')
    df_vec = pd.DataFrame(sentence_table, columns=column_labels)

#     cleaned_df["sentimentoNumerico"] = cleaned_df["sentimento"].replace({'NEGATIVE': -1, 'POSITIVE': 1, 'NEUTRAL': 0})

#     # Definir o índice do DataFrame df_vec como o mesmo índice de df_processada['sentimentoNumerico']
#     df_vec.set_index(cleaned_df["sentimentoNumerico"].index, inplace=True)

    df_vec['sentimento'] = cleaned_df["sentimento_revisto"]
#     df_vec = df_vec.dropna()

    return df_vec

# %%
df_pre_trained = create_sentence_vector(model_cbow, df)
df_pre_trained
# Out:
#                                                   Frase    Vetor1    Vetor2
# 0                           ['minuto', 'touro', 'ouro']  0.194111 -0.086163  \
# 1                                               ['sim']  0.109873 -0.062076
# 2                        ['queria', 'saber', 'banking']  0.114653 -0.154823
# 3              ['palmas', 'palmas', 'palmas', 'palmas']  0.215186 -0.092701
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...  0.204283 -0.116142
# ...                                                 ...       ...       ...
# 5662                        ['excelente', 'explicação']  0.156762 -0.134906
# 5663  ['tá', 'diminuído', 'limite', 'do', 'cartão', ...  0.167840 -0.116767
# 5664            ['atendam', 'telefone', 'amor', 'deus']  0.136519 -0.113854
# 5665  ['muito', 'grato', 'todo', 'esforço', 'você', ...  0.160386 -0.116060
# 5666  ['morning', 'call', 'não', 'mais', 'aparecendo...  0.156320 -0.132666
#
#         Vetor3    Vetor4    Vetor5    Vetor6    Vetor7    Vetor8    Vetor9
# 0     0.150576 -0.034733 -0.066786  0.122470  0.027893  0.064956  0.005728  \
# 1     0.187268 -0.213734  0.046350  0.118452 -0.025577 -0.149704  0.143837
# 2     0.213298 -0.070127  0.017422  0.120094  0.008558  0.016445  0.034044
# 3     0.254579 -0.083714  0.099877  0.371233  0.050387 -0.127568  0.118620
# 4     0.207498 -0.040869  0.002747  0.203083  0.013339  0.027435  0.052543
# ...        ...       ...       ...       ...       ...       ...       ...
# 5662  0.226852 -0.045667  0.064145  0.179836  0.001532 -0.080106 -0.059974
# 5663  0.164306 -0.076104  0.005502  0.163799 -0.007834 -0.001640  0.070826
# 5664  0.161438 -0.110917  0.034236  0.139376  0.029379 -0.063767  0.037123
# 5665  0.159980 -0.082443 -0.007597  0.142808  0.007682  0.011144  0.038226
# 5666  0.195870 -0.072017  0.011870  0.183802 -0.006948 -0.003709  0.039860
#
#       ...   Vetor42   Vetor43   Vetor44   Vetor45   Vetor46   Vetor47
# 0     ...  0.046650 -0.142142  0.131115  0.063196  0.025213  0.094671  \
# 1     ...  0.031963 -0.051879  0.235329 -0.005905  0.000182 -0.029570
# 2     ...  0.023741 -0.061997  0.112366  0.059400 -0.006027  0.117726
# 3     ... -0.090724  0.021903  0.221911  0.072890  0.119573 -0.004307
# 4     ... -0.011755 -0.058785  0.153089  0.070365 -0.001163  0.095111
# ...   ...       ...       ...       ...       ...       ...       ...
# 5662  ... -0.077624  0.021257  0.139206  0.068294  0.009093  0.062578
# 5663  ... -0.000848 -0.052661  0.149399  0.086086  0.036590  0.057364
# 5664  ...  0.000793 -0.079159  0.139690  0.086531  0.027053  0.063675
# 5665  ...  0.011884 -0.071462  0.121843  0.085297 -0.001010  0.092900
# 5666  ... -0.007778 -0.050418  0.134998  0.082059  0.006806  0.077923
#
#        Vetor48   Vetor49   Vetor50  sentimento
# 0    -0.001749 -0.002428  0.263365           1
# 1    -0.064395 -0.025853  0.185357           0
# 2    -0.055369 -0.011474  0.152972           1
# 3    -0.091760  0.027266  0.144531           1
# 4    -0.030487  0.005549  0.144212           1
# ...        ...       ...       ...         ...
# 5662 -0.032271 -0.032976  0.160159          -1
# 5663 -0.037924  0.033811  0.165939          -1
# 5664 -0.031798  0.055869  0.187216          -1
# 5665 -0.027534  0.014417  0.155917          -1
# 5666 -0.015977  0.027076  0.135846          -1
#
# [5667 rows x 52 columns]

# %%
# Exportando o csv com o resultado da aplicação do word2vec com os vetores pré treinados 
df_pre_trained.to_csv('..\\output\\word2vec_cbow.csv',encoding='utf-8', index=False, header=True, )

# %% [markdown]
# ### Word2Vec com o corpus

# %% [markdown]
# Nesta etapa será realizado o processamento a partir do zero, assim será possível ter dois modelos diferentes permitindo uma melhor oportunidade para realizar os testes.

# %%
# Abrindo a base já pré-processada 
df = pd.read_csv('../output/sentimento_revisto.csv')
df
# Out:
#                          autor
# 0                   lmviapiana  \
# 1                 vanilson_dos
# 2                  ricktolledo
# 3        paularodrigues.invest
# 4                rafael_miller
# ...                        ...
# 5662  perspectiveinvestimentos
# 5663              marlenenelso
# 5664            eduardocolares
# 5665             jayipacderota
# 5666                 bfmarilia
#
#                                                   texto sentimento
# 0                                  Minuto touro de ouro   POSITIVE  \
# 1                                      @ricktolledo Sim    NEUTRAL
# 2     Queria saber se a Btg banking é a própria btg ...   POSITIVE
# 3                                                  👏👏👏👏    NEUTRAL
# 4     Vamos ajudar o Brasil na principal categoria d...   POSITIVE
# ...                                                 ...        ...
# 5662                               Excelente explicação   POSITIVE
# 5663  Porque  o brg tá  diminuído  o limite  do cart...   NEGATIVE
# 5664               Atendam o telefone pelo amor de Deus   POSITIVE
# 5665  Estou muito grato por todo o esforço que você ...   POSITIVE
# 5666  @btgpactual pq o morning call não está mais ap...   NEGATIVE
#
#      tipoInteracao  anomalia  probabilidadeAnomalia
# 0       comentário         0                     38  \
# 1         resposta         0                     17
# 2       comentário         0                     20
# 3       comentário         0                     15
# 4       comentário         0                     41
# ...            ...       ...                    ...
# 5662    comentário         0                     15
# 5663    comentário         1                     53
# 5664    comentário         0                     28
# 5665    comentário         1                     52
# 5666    comentário         0                     28
#
#                                                linkPost  processado
# 0     https://www.instagram.com/p/CapXhB5Lvas/#17977...           0  \
# 1     https://www.instagram.com/p/CapXhB5Lvas/#17842...           0
# 2     https://www.instagram.com/p/CapXhB5Lvas/#17935...           0
# 3     https://www.instagram.com/p/CaptWrtOT8U/#17943...           0
# 4     https://www.instagram.com/p/CapoqJ3Ne7a/#17972...           0
# ...                                                 ...         ...
# 5662  https://www.instagram.com/p/ClgWR-Ov2H1/#18001...           0
# 5663  https://www.instagram.com/p/ClgWR-Ov2H1/#17878...           0
# 5664  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5665  https://www.instagram.com/p/CllkSBOuKlJ/#17960...           0
# 5666  https://www.instagram.com/p/CllkSBOuKlJ/#17975...           0
#
#       contemHyperlink                                    texto_e_palavra
# 0                   0                               Minuto touro de ouro  \
# 1                   0                                   @ricktolledo Sim
# 2                   0  Queria saber se a Btg banking é a própria btg ...
# 3                   0                       palmas palmas palmas palmas
# 4                   0  Vamos ajudar o Brasil na principal categoria d...
# ...               ...                                                ...
# 5662                0                               Excelente explicação
# 5663                0  Porque  o brg tá  diminuído  o limite  do cart...
# 5664                0               Atendam o telefone pelo amor de Deus
# 5665                0  Estou muito grato por todo o esforço que você ...
# 5666                0  @btgpactual pq o morning call não está mais ap...
#
#                                        texto_tokenizado  sentimento_revisto
# 0                           ['minuto', 'touro', 'ouro']                   1  \
# 1                                               ['sim']                   0
# 2             ['queria', 'saber', 'banking', 'própria']                   1
# 3              ['palmas', 'palmas', 'palmas', 'palmas']                   1
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...                   1
# ...                                                 ...                 ...
# 5662                        ['excelente', 'explicação']                  -1
# 5663  ['porque', 'brg', 'tá', 'diminuído', 'limite',...                  -1
# 5664            ['atendam', 'telefone', 'amor', 'deus']                  -1
# 5665  ['grato', 'todo', 'esforço', 'rendeu', 'invest...                  -1
# 5666  ['morning', 'call', 'aparecendo', 'spotify', '...                  -1
#
#                                       texto_tokenizado2
# 0                           ['minuto', 'touro', 'ouro']
# 1                                               ['sim']
# 2                        ['queria', 'saber', 'banking']
# 3              ['palmas', 'palmas', 'palmas', 'palmas']
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...
# ...                                                 ...
# 5662                        ['excelente', 'explicação']
# 5663  ['tá', 'diminuído', 'limite', 'do', 'cartão', ...
# 5664            ['atendam', 'telefone', 'amor', 'deus']
# 5665  ['muito', 'grato', 'todo', 'esforço', 'você', ...
# 5666  ['morning', 'call', 'não', 'mais', 'aparecendo...
#
# [5667 rows x 13 columns]

# %%
# Definindo qual coluna será utilizada para treinar o modelo 
input_training = df['texto_tokenizado2']

# %%
# Treinando o word2vec com o corpus
model_corpus = Word2Vec(input_training, min_count=1)

# %%
# Função que soma todas as palavras e cria as colunas
def create_sentence_vector(model, cleaned_df):
    sentence_table = []
    for sentence in cleaned_df['texto_tokenizado']:
        word_vectors = [model.wv[word] for word in sentence if word in model.wv]
        if len(word_vectors) > 0:
            sentence_vector = sum(word_vectors) / len(word_vectors)
        else:
            sentence_vector = [None] * 100  # Cria uma lista de 100 elementos None
        sentence_table.append((sentence, *sentence_vector[:50]))  # Adiciona apenas os primeiros 50 elementos do vetor

    column_labels = ['Frase']
    for i in range(50):
        column_labels.append(f'Vetor{i+1}')
    df_vec = pd.DataFrame(sentence_table, columns=column_labels)

#     cleaned_df["sentimentoNumerico"] = cleaned_df["sentimento"].replace({'NEGATIVE': -1, 'POSITIVE': 1, 'NEUTRAL': 0})

#     # Definir o índice do DataFrame df_vec como o mesmo índice de df_processada['sentimentoNumerico']
#     df_vec.set_index(cleaned_df["sentimentoNumerico"].index, inplace=True)

    df_vec['sentimento'] = cleaned_df["sentimento_revisto"]
    df_vec = df_vec.dropna()

    return df_vec

# %%
# Criando os vetores
df_corpus = create_sentence_vector(model_corpus, df)
df_corpus
# Out:
#                                                   Frase    Vetor1    Vetor2
# 0                           ['minuto', 'touro', 'ouro']  0.078066 -0.681861  \
# 1                                               ['sim']  0.219127 -0.408984
# 2             ['queria', 'saber', 'banking', 'própria']  0.139843 -0.536218
# 3              ['palmas', 'palmas', 'palmas', 'palmas']  0.146434 -0.234622
# 4     ['vamos', 'ajudar', 'brasil', 'principal', 'ca...  0.151519 -0.500928
# ...                                                 ...       ...       ...
# 5662                        ['excelente', 'explicação']  0.233356 -0.433924
# 5663  ['porque', 'brg', 'tá', 'diminuído', 'limite',...  0.156947 -0.584779
# 5664            ['atendam', 'telefone', 'amor', 'deus']  0.145733 -0.585373
# 5665  ['grato', 'todo', 'esforço', 'rendeu', 'invest...  0.170928 -0.599077
# 5666  ['morning', 'call', 'aparecendo', 'spotify', '...  0.159006 -0.553886
#
#         Vetor3    Vetor4    Vetor5    Vetor6    Vetor7    Vetor8    Vetor9
# 0    -0.242816 -0.287935 -0.052421  0.331101 -0.139809 -0.379450  0.267952  \
# 1    -0.176726 -0.270843  0.154609  0.169897 -0.016856 -0.248304  0.197370
# 2    -0.217435 -0.219593 -0.017553  0.193954 -0.051410 -0.258538  0.166662
# 3    -0.173836 -0.255587  0.160331  0.161181 -0.023813 -0.191149  0.076497
# 4    -0.217571 -0.271197 -0.014306  0.233144 -0.057781 -0.306150  0.215858
# ...        ...       ...       ...       ...       ...       ...       ...
# 5662 -0.272217 -0.314453 -0.036260  0.256108 -0.033117 -0.292216  0.242472
# 5663 -0.194561 -0.271622 -0.046859  0.263095 -0.090514 -0.318417  0.241259
# 5664 -0.215295 -0.317303 -0.041272  0.284987 -0.116252 -0.368979  0.256614
# 5665 -0.227178 -0.292141 -0.052094  0.276457 -0.083850 -0.347391  0.266818
# 5666 -0.249320 -0.296590 -0.040441  0.251918 -0.065491 -0.342148  0.229450
#
#       ...   Vetor42   Vetor43   Vetor44   Vetor45   Vetor46   Vetor47
# 0     ... -0.211810  0.132065 -0.106570  0.100519  0.056235  0.211425  \
# 1     ... -0.338304  0.263537  0.065959  0.021564  0.175807  0.181400
# 2     ... -0.251460  0.155440 -0.043917  0.123936  0.185161  0.097498
# 3     ... -0.356565  0.168509  0.098124  0.088115  0.154685  0.217300
# 4     ... -0.231650  0.143755 -0.044758  0.106567  0.123410  0.163982
# ...   ...       ...       ...       ...       ...       ...       ...
# 5662  ... -0.156774  0.208884 -0.075381  0.039420  0.062635  0.112375
# 5663  ... -0.234681  0.149966 -0.067125  0.093000  0.116992  0.154841
# 5664  ... -0.231181  0.162746 -0.076660  0.088449  0.105912  0.181612
# 5665  ... -0.218465  0.155783 -0.084950  0.086562  0.100502  0.169236
# 5666  ... -0.231244  0.184411 -0.075312  0.110748  0.132141  0.163654
#
#        Vetor48   Vetor49   Vetor50  sentimento
# 0     0.015619 -0.055449 -0.076335           1
# 1    -0.136190 -0.056663 -0.056629           0
# 2    -0.046922 -0.040375 -0.083413           1
# 3    -0.187343 -0.033554 -0.157490           1
# 4    -0.049926 -0.079451 -0.083599           1
# ...        ...       ...       ...         ...
# 5662 -0.058631 -0.109948 -0.073896          -1
# 5663 -0.043088 -0.060749 -0.081761          -1
# 5664 -0.021021 -0.070964 -0.086959          -1
# 5665 -0.014393 -0.080405 -0.071225          -1
# 5666 -0.030637 -0.064789 -0.085968          -1
#
# [5667 rows x 52 columns]

# %%
# Exportando o csv com o resultado da aplicação do word2vec com os vetores do corpus
df_corpus.to_csv('..\\output\\word2vec_corpus.csv',encoding='utf-8', index=False, header=True, )
